# %%
import numpy
filename="power.csv"
raw_data=open(filename,'rt')
data=numpy.loadtxt(raw_data,delimiter=",")

# %%
data.shape
# Out:
# (9568, 5)

# %%
X=data[:,:4]
Y=data[:,4]
prop=0.9*len(data)

X_train=X[:round(prop),:]
X_test=X[round(prop):,:]
Y_train=Y[:round(prop)]
Y_test=Y[round(prop):]

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %%
X1_20=X_train[:20,0]
X2_20=X_train[:20,1]
X3_20=X_train[:20,2]
X4_20=X_train[:20,3]
Y_20=Y_train[:20]
X_train.shape
# Out:
# (8611, 4)

# %%
plt.scatter(X1_20,Y_20)
plt.show()

# %%
plt.scatter(X2_20,Y_20)
plt.show()

# %%
plt.scatter(X3_20,Y_20)
plt.show()

# %%
plt.scatter(X4_20,Y_20)
plt.show()

# %%
regr=linear_model.LinearRegression()
regr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions=regr.predict(X_test)
mean_squared_error(Y_test,predictions)
from sklearn.metrics import r2_score 
r2_score(Y_test,predictions)
# Out:
# 0.9277954175464138

# %%
regr.coef_[0]
# Out:
# array([-1.97630359, -0.23422523,  0.06774653, -0.15925108])

# %%
plt.scatter(X_test[:,0],Y_test[:],color='black')
plt.plot(X_test[:,0],-1.97630359*X_test[:,0]+(-0.23422523)*X_test[:,1]+0.06774653*X_test[:,2]+(-0.15925108)*X_test[:,3]+448.9699443,
         color='blue')

plt.show()

# %%
X_test[:10]
# Out:
# array([[  21.93,   58.96, 1014.23,   58.58],
#        [  10.14,   45.01, 1018.12,   94.32],
#        [  14.04,   48.79, 1017.62,   75.25],
#        [  24.14,   60.07, 1016.56,   58.08],
#        [  13.48,   41.44, 1015.64,   71.46],
#        [  14.26,   43.34, 1017.24,   81.54],
#        [  19.99,   65.94, 1012.28,   75.42],
#        [  16.52,   53.16, 1014.68,   76.82],
#        [  22.75,   58.79, 1011.44,   84.47],
#        [  15.31,   40.66, 1016.46,   84.64]])
